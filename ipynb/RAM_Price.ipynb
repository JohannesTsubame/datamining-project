# %%
import pandas as pd

# %%
df = pd.read_csv("../Dataset/ram_pricing_intelligence_2026.csv")

df.head()
# Out:
#   ram_generation     brand    seller_id condition  \
# 0           DDR4  SK hynix  Seller_0001      Used
# 1           DDR4    A-Tech  Seller_0002       New
# 2           DDR4   Crucial  Seller_0003      Used
# 3           DDR4  SK hynix  Seller_0004      Used
# 4           DDR4       RAM  Seller_0005      Used
#
#                                                title  capacity_gb  \
# 0  SK Hynix 64GB 4DRx4 PC4-2400T DDR4 ECC Server ...         64.0
# 1  A-Tech 32GB 2x 16GB PC4-21300 Laptop SODIMM 26...         32.0
# 2  16GB Crucial Micron DDR4-2133 PC4-17000 RDIMM ...         16.0
# 3  SK HYNIX 32GB HMA84GR7MFR4N-UH DDR4-2400 2Rx4 ...         32.0
# 4  Mixed Brand 8GB DDR4 Desktop RAM PC4 UDIMM - C...          8.0
#
#    bus_speed_mhz unit_type   price  wasPrice  available    sold  \
# 0         2400.0    Single  229.00       NaN        6.0     2.0
# 1         2666.0  Dual Kit  231.98       NaN       10.0  1728.0
# 2         2133.0    Single   57.99       NaN        8.0    28.0
# ...

# %%
df.shape
# Out:
# (2899, 17)

# %%
df.isna().sum()
# Out:
# ram_generation       0
# brand                4
# seller_id            0
# condition            0
# title                0
# capacity_gb         36
# bus_speed_mhz      627
# unit_type            0
# price                0
# wasPrice          2776
# available         1129
# sold              1979
# itemLocation         0
# lastUpdated        789
# mpn               1081
# type               107
# is_bulk_server       0
# dtype: int64

# %%
for col in df.columns:
    print(f"{col} : {df[col].duplicated().sum()}")
# Out:
# ram_generation : 2896
# brand : 2749
# seller_id : 1623
# condition : 2893
# title : 78
# capacity_gb : 2877
# bus_speed_mhz : 2867
# unit_type : 2896
# price : 1968
# wasPrice : 2796
# available : 2852
# sold : 2775
# itemLocation : 2044
# lastUpdated : 1259
# mpn : 1578
# type : 2759
# is_bulk_server : 2897
