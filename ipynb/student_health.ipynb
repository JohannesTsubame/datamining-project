# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../Dataset/student_health_dataset_50k.csv")

df.head()
# Out:
#    student_id            timestamp  sleep_duration  heart_rate    bmi  \
# 0        1102  2025-01-01 00:00:00            9.29        67.4  28.56
# 1        1435  2025-01-01 01:00:00            9.33        57.2  30.17
# 2        1860  2025-01-01 02:00:00            8.33        73.7  19.93
# 3        1270  2025-01-01 03:00:00            5.60        61.9  22.02
# 4        1106  2025-01-01 04:00:00            9.10        69.6  20.85
#
#    calorie_expenditure  step_count  exercise_duration  water_intake diet_type  \
# 0               2113.0        5227               91.3          2.08       veg
# 1               2060.0       14460               67.0          2.57       veg
# 2               2236.0       14589               52.6          1.93   non-veg
# 3               2650.0       12618               55.2          2.97       veg
# 4               1985.0       14518               27.1          3.09   non-veg
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   student_id               50000 non-null  int64
#  1   timestamp                50000 non-null  str
#  2   sleep_duration           50000 non-null  float64
#  3   heart_rate               50000 non-null  float64
#  4   bmi                      50000 non-null  float64
#  5   calorie_expenditure      50000 non-null  float64
#  6   step_count               50000 non-null  int64
#  7   exercise_duration        50000 non-null  float64
#  8   water_intake             50000 non-null  float64
#  9   diet_type                50000 non-null  str
#  10  stress_level             50000 non-null  str
#  11  sleep_quality            50000 non-null  str
#  12  physical_activity_level  50000 non-null  str
#  13  smoking_alcohol          50000 non-null  str
# ...

# %%
for i in range(9, 16):
    col = df.columns[i]
    print(f"{col} : \n{df[col].unique()}")
    print("=====================================")
# Out:
# diet_type :
# <StringArray>
# ['veg', 'non-veg', 'balanced']
# Length: 3, dtype: str
# ...
# stress_level :
# <StringArray>
# ['high', 'medium', 'low']
# Length: 3, dtype: str
# ...
# sleep_quality :
# <StringArray>
# ['average', 'poor', 'good']
# Length: 3, dtype: str
# ...
# physical_activity_level :
# <StringArray>
# ['active', 'sedentary', 'moderate']
# Length: 3, dtype: str
# ...
# smoking_alcohol :
# <StringArray>
# ['yes', 'occasional', 'no']
# Length: 3, dtype: str
# ...
# gender :
# <StringArray>
# ['other', 'male', 'female']
# Length: 3, dtype: str
# ...
# health_condition :
# <StringArray>
# ['at-risk', 'unhealthy', 'fit']
# Length: 3, dtype: str
# ...

# %%
df_date = pd.to_datetime(df["timestamp"])

df["timestamp"] =  df_date
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   student_id               50000 non-null  int64
#  1   timestamp                50000 non-null  datetime64[us]
#  2   sleep_duration           50000 non-null  float64
#  3   heart_rate               50000 non-null  float64
#  4   bmi                      50000 non-null  float64
#  5   calorie_expenditure      50000 non-null  float64
#  6   step_count               50000 non-null  int64
#  7   exercise_duration        50000 non-null  float64
#  8   water_intake             50000 non-null  float64
#  9   diet_type                50000 non-null  str
#  10  stress_level             50000 non-null  str
#  11  sleep_quality            50000 non-null  str
#  12  physical_activity_level  50000 non-null  str
#  13  smoking_alcohol          50000 non-null  str
# ...

# %% [markdown]
# # Visualization

# %% [markdown]
# ### Sleep Duration

# %%
sleep = df["sleep_duration"]

# %%
for i in range(9, 16):
    col = df.columns[i]
    name = df[col].unique()
    value = df[col].value_counts()

    plt.bar(name, value)
    plt.title(col)
    plt.xlabel("Name")
    plt.ylabel("Distribution")
    plt.show()
